# %%
#piedra papel o tijera aleatorio 
import random

jugador = input("¿Cómo deseas llamarte?")
score = [0] 
aleatorio = random.randint(0,3)
juego = ['1. Piedra' , '2. Papel', '3. Tijera', '4. Salir']

while True:
    print(f"Bienvenido {jugador} al juego de piedra, papel o tijera")
    print(*juego, sep = '\n')
    opcion = int(input("Ingrese una opcion:"))
    if opcion == 1:
       elijeuser = juego[2]
    elif opcion == 2:
       elijeuser = juego[1]
    elif opcion == 3:
       elijeuser = juego[0]
    elif opcion == 4:
       elijeuser = juego[3]
       exit()

    print(f"El jugador escoje: {elijeuser}")
    
    if aleatorio == 1:
       elijeuserpc = juego[0]
    elif aleatorio == 2:
       elijeuserpc = juego[1]
    elif aleatorio == 3:
       elijeuserpc = juego[2]
       
    print(f"La maquina escoje {elijeuserpc}")

    



    print("...")

    if elijeuser == elijeuserpc:
        score_acumulate = score.insert(0, 0)
        print("Empate")
    elif elijeuser == "Tijera" and elijeuserpc == "Papel":
        score_acumulate = score.insert(0,10)
        print("Ganaste")
    elif elijeuser == "Papel" and elijeuserpc == "Piedra":
        score_acumulate = score.insert(0, 10)
        print("Ganaste")
    elif elijeuser == "Piedra" and elijeuserpc == "Tijera":
        score_acumulate = score.insert(0, 10)
        print("Ganaste")
    elif elijeuser == "Tijera" and elijeuserpc == "Piedra":
        score_acumulate = score.insert(0, 10)
        print("Ganaste")
    elif elijeuser == "Piedra" and elijeuserpc == "Papel":
        score_acumulate = score.insert(0, 10)
        print("Ganaste")
    elif elijeuser == "Papel" and elijeuserpc == "Tijera":
        score_acumulate = score.insert(0, 10)
        print("Ganaste")
    
    
    print("...")
    
    print("El jugador ha ganado puntos:  " + str(score[0]))

    total_score = sum(score)
    print(f"Su {jugador} de puntos es: {total_score}")
   
    print("...")
    
    juega_de_nuevo = input("¿Te gustaría jugar otra vez?: s/n)")
    if juega_de_nuevo.lower() != 's':
        print("Gracias por jugar")
        break
# Out:
# Bienvenido mafer al juego de piedra, papel o tijera
# Piedra
# Papel
# Tijera
# Salir
# El jugador escoje: Papel
# La maquina escoje Tijera
# ...
# Ganaste
# ...
# El jugador ha ganado puntos:  10
# Su mafer de puntos es: 10
# ...
# Bienvenido mafer al juego de piedra, papel o tijera
# Piedra
# Papel
# Tijera
# Salir
# El jugador escoje: Piedra
# La maquina escoje Tijera
# ...
# Ganaste
# ...
# El jugador ha ganado puntos:  10
# Su mafer de puntos es: 20
# ...
# Gracias por jugar
