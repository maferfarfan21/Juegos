# %%
import pygame
import sys

pygame.init()

WIDTH, HEIGHT = 00, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Navegación de Pantallas en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)
background = pygame.image.load("./images/Frame_8.jpg").convert()
# Pantallas
pantalla_actual = 1
#Funcion para mostrar imagen en pantalla
def agregar_imagen(ruta_imagen, posicion):
    imagen = pygame.image.load(ruta_imagen)
    screen.blit(imagen, posicion)


def pantalla_1():
    screen.blit(background, (0, 0))
    agregar_imagen('./images/tittle.png', (146, 85) )
    agregar_imagen('./images/figures.png', (210, 350) )
        
    
    pygame.draw.rect(screen, RED, (300, 200, 200, 50))  # Botón 1
    texto = font.render("Pantalla 1", True, (0, 0, 0))
    screen.blit(texto, (350, 210))

def pantalla_2():
    screen.fill(WHITE)
    pygame.draw.rect(screen, RED, (300, 200, 200, 50))  # Botón 2
    texto = font.render("Pantalla 2", True, (0, 0, 0))
    screen.blit(texto, (350, 210))

def pantalla_3():
    screen.fill(WHITE)
    pygame.draw.rect(screen, RED, (300, 200, 200, 50))  # Botón 3
    texto = font.render("Pantalla 3", True, (0, 0, 0))
    screen.blit(texto, (350, 210))

def pantalla_4():
    screen.fill(WHITE)
    pygame.draw.rect(screen, RED, (300, 200, 200, 50))  # Botón 4
    texto = font.render("Pantalla 4", True, (0, 0, 0))
    screen.blit(texto, (350, 210))

def cambiar_pantalla(pantalla):
    global pantalla_actual
    pantalla_actual = pantalla

def manejar_eventos():
    global pantalla_actual
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        if event.type == pygame.MOUSEBUTTONDOWN and event.button == 1:
            if pantalla_actual == 1:
                if 300 <= event.pos[0] <= 500 and 200 <= event.pos[1] <= 250:
                    cambiar_pantalla(2)
            elif pantalla_actual == 2:
                if 300 <= event.pos[0] <= 500 and 200 <= event.pos[1] <= 250:
                    cambiar_pantalla(3)
            elif pantalla_actual == 3:
                if 300 <= event.pos[0] <= 500 and 200 <= event.pos[1] <= 250:
                    cambiar_pantalla(4)
            elif pantalla_actual == 4:
                if 300 <= event.pos[0] <= 500 and 200 <= event.pos[1] <= 250:
                    cambiar_pantalla(1)

def main():
    global pantalla_actual
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_2()
        elif pantalla_actual == 3:
            pantalla_3()
        elif pantalla_actual == 4:
            pantalla_4()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 1 line 9
#      <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W2sZmlsZQ%3D%3D?line=95'>96</a>         clock.tick(60)  # Límite de velocidad de cuadros
#      <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W2sZmlsZQ%3D%3D?line=97'>98</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W2sZmlsZQ%3D%3D?line=98'>99</a>     main()
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 1 line 9
#      <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W2sZmlsZQ%3D%3D?line=91'>92</a>     pantalla_4()
#      <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W2sZmlsZQ%3D%3D?line=93'>94</a> pygame.display.flip()
# ...

# %%
pip install pygame_textinput
# Out:
# ...
#   Using cached pygame_textinput-1.0.1-py3-none-any.whl (7.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 800, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultados
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

def pantalla_1():
    screen.fill(WHITE)
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    screen.blit(texto_ingrese_nickname, (100, 200))
    
    pygame.draw.rect(screen, RED, (100, 250, 600, 50))  # Cuadro de entrada
    texto_nickname = font.render(nickname, True, (0, 0, 0))
    screen.blit(texto_nickname, (110, 260))
    
    # Botones para las elecciones del jugador
    pygame.draw.rect(screen, RED, (100, 400, 200, 50))  # Piedra
    pygame.draw.rect(screen, RED, (350, 400, 200, 50))  # Papel
    pygame.draw.rect(screen, RED, (600, 400, 200, 50))  # Tijera
    
    texto_piedra = font.render("Piedra", True, (0, 0, 0))
    screen.blit(texto_piedra, (160, 410))
    
    texto_papel = font.render("Papel", True, (0, 0, 0))
    screen.blit(texto_papel, (410, 410))
    
    texto_tijera = font.render("Tijera", True, (0, 0, 0))
    screen.blit(texto_tijera, (660, 410))

def jugar_eleccion(jugador):
    computadora = random.choice(elecciones)
    global resultado
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
    else:
        resultado = "¡Perdiste!"
    
    return computadora

def manejar_eventos():
    global nickname
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.MOUSEBUTTONDOWN and event.button == 1:
            x, y = event.pos
            if 100 <= x <= 300 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Piedra")
            elif 350 <= x <= 550 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Papel")
            elif 600 <= x <= 800 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Tijera")
        elif event.type == pygame.KEYDOWN and event.key == pygame.K_RETURN:
            if nickname:
                resultado_jugador = jugar_eleccion("Piedra")  # Otra vez, puedes cambiar la elección inicial
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_BACKSPACE:
                nickname = nickname[:-1]
            else:
                nickname += event.unicode

def main():
    global resultado, nickname
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        pantalla_1()
        
        # Mostrar el nickname ingresado
        texto_nickname = font.render("Nickname: " + nickname, True, (0, 0, 0))
        screen.blit(texto_nickname, (100, 350))
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 3 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W5sZmlsZQ%3D%3D?line=104'>105</a>         clock.tick(60)  # Límite de velocidad de cuadros
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W5sZmlsZQ%3D%3D?line=106'>107</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W5sZmlsZQ%3D%3D?line=107'>108</a>     main()
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 3 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#W5sZmlsZQ%3D%3D?line=100'>101</a> screen.blit(texto_nickname, (100, 350))
# ...

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 800, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultado de la partida
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

# Puntaje del jugador
puntaje = 0

# Variable para controlar la pantalla actual
pantalla_actual = 1

def cargar_imagen(nombre_archivo):
    return pygame.image.load(nombre_archivo).convert_alpha()

# Cargar imágenes de las elecciones (piedra, papel y tijera)
img_piedra = cargar_imagen("./images/piedra.png")
img_papel = cargar_imagen("./images/piedra.png")
img_tijera = cargar_imagen("./images/piedra.png")

# Posiciones de las imágenes de elecciones
pos_piedra = (150, 350)
pos_papel = (350, 350)
pos_tijera = (550, 350)

def pantalla_1():
    global nickname, pantalla_actual
    screen.fill(WHITE)
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    screen.blit(texto_ingrese_nickname, (100, 200))
    
    pygame.draw.rect(screen, RED, (100, 250, 600, 50))  # Cuadro de entrada
    
    # Obtener el texto ingresado en el campo de entrada
    input_text = font.render(nickname, True, (0, 0, 0))
    screen.blit(input_text, (110, 260))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    if pantalla_actual == 1:
        # Botón para iniciar el juego
        pygame.draw.rect(screen, RED, (350, 400, 200, 50))
        texto_iniciar = font.render("Iniciar Juego", True, (0, 0, 0))
        screen.blit(texto_iniciar, (360, 410))

def pantalla_juego():
    global resultado, puntaje
    screen.fill(WHITE)
    
    # Mostrar nickname y puntaje
    texto_nickname = font.render(f"Nickname: {nickname}", True, (0, 0, 0))
    screen.blit(texto_nickname, (10, 10))
    
    texto_puntaje = font.render(f"Puntaje: {puntaje}", True, (0, 0, 0))
    screen.blit(texto_puntaje, (10, 50))
    
    # Mostrar imágenes de las elecciones
    screen.blit(img_piedra, pos_piedra)
    screen.blit(img_papel, pos_papel)
    screen.blit(img_tijera, pos_tijera)
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    # Botón para repetir partida
    pygame.draw.rect(screen, RED, (350, 500, 200, 50))
    texto_repetir = font.render("Repetir Partida", True, (0, 0, 0))
    screen.blit(texto_repetir, (360, 510))

def reiniciar_partida():
    global resultado, puntaje
    resultado = ""
    puntaje = 0

def jugar_eleccion(jugador):
    global resultado, puntaje
    computadora = random.choice(elecciones)
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
        puntaje += 1
    else:
        resultado = "¡Perdiste!"
        puntaje -= 1
    
    return computadora

def manejar_eventos():
    global nickname, pantalla_actual
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.MOUSEBUTTONDOWN and event.button == 1:
            x, y = event.pos
            if 100 <= x <= 300 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Piedra")
            elif 350 <= x <= 550 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Papel")
            elif 600 <= x <= 800 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Tijera")
            elif pantalla_actual == 1 and 350 <= x <= 550 and 400 <= y <= 450:
                if nickname:
                    pantalla_actual = 2
        elif event.type == pygame.KEYDOWN:
            if pantalla_actual == 1:
                if event.key == pygame.K_BACKSPACE:
                    nickname = nickname[:-1]
                elif event.key == pygame.K_RETURN:
                    if nickname:
                        pantalla_actual = 2
                else:
                    nickname += event.unicode
            elif pantalla_actual == 2:
                if event.key == pygame.K_r:
                    # Reiniciar la partida
                    reiniciar_partida()
                elif event.key == pygame.K_p:
                    # El jugador seleccionó "Piedra"
                    resultado_jugador = jugar_eleccion("Piedra")
                elif event.key == pygame.K_a:
                    # El jugador seleccionó "Papel"
                    resultado_jugador = jugar_eleccion("Papel")
                elif event.key == pygame.K_t:
                    # El jugador seleccionó "Tijera"
                    resultado_jugador = jugar_eleccion("Tijera")

def main():
    global resultado, nickname
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_juego()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 4 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X10sZmlsZQ%3D%3D?line=170'>171</a>         clock.tick(60)  # Límite de velocidad de cuadros
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X10sZmlsZQ%3D%3D?line=172'>173</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X10sZmlsZQ%3D%3D?line=173'>174</a>     main()
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 4 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X10sZmlsZQ%3D%3D?line=166'>167</a>     pantalla_juego()
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X10sZmlsZQ%3D%3D?line=168'>169</a> pygame.display.flip()
# ...

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 800, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultado de la partida
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

# Puntaje del jugador
puntaje = 0

# Variable para controlar la pantalla actual
pantalla_actual = 1

def cargar_imagen(nombre_archivo):
    return pygame.image.load(nombre_archivo).convert_alpha()

# Cargar imágenes de las elecciones (piedra, papel y tijera)
img_piedra = cargar_imagen("./images/piedra.png")
img_papel = cargar_imagen("./images/piedra.png")
img_tijera = cargar_imagen("./images/piedra.png")

# Posiciones de las imágenes de elecciones
pos_piedra = (150, 350)
pos_papel = (350, 350)
pos_tijera = (550, 350)

def pantalla_1():
    global nickname, pantalla_actual
    screen.fill(WHITE)
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    screen.blit(texto_ingrese_nickname, (100, 200))
    
    pygame.draw.rect(screen, RED, (100, 250, 600, 50))  # Cuadro de entrada
    
    # Obtener el texto ingresado en el campo de entrada
    input_text = font.render(nickname, True, (0, 0, 0))
    screen.blit(input_text, (110, 260))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    if pantalla_actual == 1:
        # Botón para iniciar el juego
        pygame.draw.rect(screen, RED, (350, 400, 200, 50))
        texto_iniciar = font.render("Iniciar Juego", True, (0, 0, 0))
        screen.blit(texto_iniciar, (360, 410))

def pantalla_juego():
    global resultado, puntaje
    screen.fill(WHITE)
    
    # Mostrar nickname y puntaje
    texto_nickname = font.render(f"Nickname: {nickname}", True, (0, 0, 0))
    screen.blit(texto_nickname, (10, 10))
    
    texto_puntaje = font.render(f"Puntaje: {puntaje}", True, (0, 0, 0))
    screen.blit(texto_puntaje, (10, 50))
    
    # Mostrar imágenes de las elecciones
    screen.blit(img_piedra, pos_piedra)
    screen.blit(img_papel, pos_papel)
    screen.blit(img_tijera, pos_tijera)
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    # Botón para repetir partida
    pygame.draw.rect(screen, RED, (350, 500, 200, 50))
    texto_repetir = font.render("Repetir Partida", True, (0, 0, 0))
    screen.blit(texto_repetir, (360, 510))

def reiniciar_partida():
    global resultado, puntaje
    resultado = ""
    puntaje = 0

def jugar_eleccion(jugador):
    global resultado, puntaje
    computadora = random.choice(elecciones)
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
        puntaje += 1
    else:
        resultado = "¡Perdiste!"
        puntaje -= 1
    
    return computadora

def manejar_eventos():
    global nickname, pantalla_actual
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
        elif event.type == pygame.MOUSEBUTTONDOWN and event.button == 1:
            x, y = event.pos
            if 100 <= x <= 300 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Piedra")
            elif 350 <= x <= 550 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Papel")
            elif 600 <= x <= 800 and 400 <= y <= 450:
                resultado_jugador = jugar_eleccion("Tijera")
            elif pantalla_actual == 1 and 350 <= x <= 550 and 400 <= y <= 450:
                if nickname:
                    pantalla_actual = 2
        elif event.type == pygame.KEYDOWN:
            if pantalla_actual == 1:
                if event.key == pygame.K_BACKSPACE:
                    nickname = nickname[:-1]
                elif event.key == pygame.K_RETURN:
                    if nickname:
                        pantalla_actual = 2
            elif pantalla_actual == 2:
                if event.key == pygame.K_r:
                    # Reiniciar la partida
                    reiniciar_partida()
                elif event.key == pygame.K_p:
                    # El jugador seleccionó "Piedra"
                    resultado_jugador = jugar_eleccion("Piedra")
                elif event.key == pygame.K_a:
                    # El jugador seleccionó "Papel"
                    resultado_jugador = jugar_eleccion("Papel")
                elif event.key == pygame.K_t:
                    # El jugador seleccionó "Tijera"
                    resultado_jugador = jugar_eleccion("Tijera")

def main():
    global resultado, nickname
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_juego()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 5 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X11sZmlsZQ%3D%3D?line=168'>169</a>         clock.tick(60)  # Límite de velocidad de cuadros
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X11sZmlsZQ%3D%3D?line=170'>171</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X11sZmlsZQ%3D%3D?line=171'>172</a>     main()
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 5 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X11sZmlsZQ%3D%3D?line=164'>165</a>     pantalla_juego()
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X11sZmlsZQ%3D%3D?line=166'>167</a> pygame.display.flip()
# ...

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 800, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultado de la partida
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

# Puntaje del jugador
puntaje = 0

# Variable para controlar la pantalla actual
pantalla_actual = 1

def cargar_imagen(nombre_archivo):
    return pygame.image.load(nombre_archivo).convert_alpha()


# Cargar imágenes de las elecciones (piedra, papel y tijera)
img_piedra = cargar_imagen("./images/piedra.png")
img_papel = cargar_imagen("./images/piedra.png")
img_tijera = cargar_imagen("./images/piedra.png")

# Posiciones de las imágenes de elecciones
pos_piedra = (150, 350)
pos_papel = (350, 350)
pos_tijera = (550, 350)

def pantalla_1():
    global nickname, pantalla_actual
    screen.fill(WHITE)
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    screen.blit(texto_ingrese_nickname, (100, 200))
    
    pygame.draw.rect(screen, RED, (100, 250, 600, 50))  # Cuadro de entrada
    
    # Obtener el texto ingresado en el campo de entrada
    input_text = font.render(nickname, True, (0, 0, 0))
    screen.blit(input_text, (110, 260))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    if pantalla_actual == 1:
        # Botón para iniciar el juego
        pygame.draw.rect(screen, RED, (350, 400, 200, 50))
        texto_iniciar = font.render("Iniciar Juego", True, (0, 0, 0))
        screen.blit(texto_iniciar, (360, 410))

def pantalla_juego():
    global resultado, puntaje
    screen.fill(WHITE)
    
    # Mostrar nickname y puntaje
    texto_nickname = font.render(f"Nickname: {nickname}", True, (0, 0, 0))
    screen.blit(texto_nickname, (10, 10))
    
    texto_puntaje = font.render(f"Puntaje: {puntaje}", True, (0, 0, 0))
    screen.blit(texto_puntaje, (10, 50))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    # Botón para repetir partida
    pygame.draw.rect(screen, RED, (350, 500, 200, 50))
    texto_repetir = font.render("Repetir Partida", True, (0, 0, 0))
    screen.blit(texto_repetir, (360, 510))

    # Mostrar imágenes de las elecciones solo en la segunda pantalla
    if pantalla_actual == 2:
        screen.blit(img_piedra, pos_piedra)
        screen.blit(img_papel, pos_papel)
        screen.blit(img_tijera, pos_tijera)

def reiniciar_partida():
    global resultado, puntaje
    resultado = ""
    puntaje = 0

def jugar_eleccion(jugador):
    global resultado, puntaje
    computadora = random.choice(elecciones)
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
        puntaje += 1
    else:
        resultado = "¡Perdiste!"
        puntaje -= 1
    
    return computadora

def manejar_eventos():
    global nickname, pantalla_actual
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
       
        elif event.type == pygame.KEYDOWN:
            if pantalla_actual == 1:
                if event.key == pygame.K_BACKSPACE:
                    nickname = nickname[:-1]
                elif event.key == pygame.K_RETURN:
                    if nickname:
                        pantalla_actual = 2
                else:
                    nickname += event.unicode
            elif pantalla_actual == 2:
                if event.key == pygame.K_r:
                    # Reiniciar la partida
                    reiniciar_partida()
                elif event.key == pygame.K_p:
                    # El jugador seleccionó "Piedra"
                    resultado_jugador = jugar_eleccion("Piedra")
                elif event.key == pygame.K_a:
                    # El jugador seleccionó "Papel"
                    resultado_jugador = jugar_eleccion("Papel")
                elif event.key == pygame.K_t:
                    # El jugador seleccionó "Tijera"
                    resultado_jugador = jugar_eleccion("Tijera")

def main():
    global resultado, nickname
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_juego()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 6 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=162'>163</a>         clock.tick(60)  # Límite de velocidad de cuadros
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=164'>165</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=165'>166</a>     main()
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 6 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=158'>159</a>     pantalla_juego()
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=160'>161</a> pygame.display.flip()
# ...

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 800, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultado de la partida
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

# Puntaje del jugador
puntaje = 0

# Variable para controlar la pantalla actual
pantalla_actual = 1

def cargar_imagen(nombre_archivo):
    return pygame.image.load(nombre_archivo).convert_alpha()


# Cargar imágenes de las elecciones (piedra, papel y tijera)
img_piedra = cargar_imagen("./images/piedra.png")
img_papel = cargar_imagen("./images/piedra.png")
img_tijera = cargar_imagen("./images/piedra.png")

# Posiciones de las imágenes de elecciones
pos_piedra = (150, 350)
pos_papel = (350, 350)
pos_tijera = (550, 350)

def pantalla_1():
    global nickname, pantalla_actual
    screen.fill(WHITE)
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    screen.blit(texto_ingrese_nickname, (100, 200))
    
    pygame.draw.rect(screen, RED, (100, 250, 600, 50))  # Cuadro de entrada
    
    # Obtener el texto ingresado en el campo de entrada
    input_text = font.render(nickname, True, (0, 0, 0))
    screen.blit(input_text, (110, 260))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    if pantalla_actual == 1:
        # Botón para iniciar el juego
        pygame.draw.rect(screen, RED, (350, 400, 200, 50))
        texto_iniciar = font.render("Iniciar Juego", True, (0, 0, 0))
        screen.blit(texto_iniciar, (360, 410))

def pantalla_juego():
    global resultado, puntaje
    screen.fill(WHITE)
    
    # Mostrar nickname y puntaje
    texto_nickname = font.render(f"Nickname: {nickname}", True, (0, 0, 0))
    screen.blit(texto_nickname, (10, 10))
    
    texto_puntaje = font.render(f"Puntaje: {puntaje}", True, (0, 0, 0))
    screen.blit(texto_puntaje, (10, 50))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    # Botón para repetir partida
    pygame.draw.rect(screen, RED, (350, 500, 200, 50))
    texto_repetir = font.render("Repetir Partida", True, (0, 0, 0))
    screen.blit(texto_repetir, (360, 510))

    # Mostrar imágenes de las elecciones solo en la segunda pantalla
    if pantalla_actual == 2:
        screen.blit(img_piedra, pos_piedra)
        screen.blit(img_papel, pos_papel)
        screen.blit(img_tijera, pos_tijera)

def reiniciar_partida():
    global resultado, puntaje
    resultado = ""
    puntaje = 0

def jugar_eleccion(jugador):
    global resultado, puntaje
    computadora = random.choice(elecciones)
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
        puntaje += 1
    else:
        resultado = "¡Perdiste!"
        puntaje -= 1
    
    return computadora

def manejar_eventos():
    global nickname, pantalla_actual, running  # Agregamos "running" a las variables globales
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
       
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_s:
                # Presionar la tecla "S" para salir del juego
                pygame.quit()
                sys.exit()
                
            if pantalla_actual == 1:
                if event.key == pygame.K_BACKSPACE:
                    nickname = nickname[:-1]
                elif event.key == pygame.K_RETURN:
                    if nickname:
                        pantalla_actual = 2
                else:
                    nickname += event.unicode
            elif pantalla_actual == 2:
                if event.key == pygame.K_r:
                    # Reiniciar la partida
                    reiniciar_partida()
                elif event.key == pygame.K_p:
                    # El jugador seleccionó "Piedra"
                    resultado_jugador = jugar_eleccion("Piedra")
                elif event.key == pygame.K_a:
                    # El jugador seleccionó "Papel"
                    resultado_jugador = jugar_eleccion("Papel")
                elif event.key == pygame.K_t:
                    # El jugador seleccionó "Tijera"
                    resultado_jugador = jugar_eleccion("Tijera")

def main():
    global resultado, nickname, running
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_juego()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 7 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X13sZmlsZQ%3D%3D?line=167'>168</a>         clock.tick(60)  # Límite de velocidad de cuadros
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X13sZmlsZQ%3D%3D?line=169'>170</a> if __name__ == "__main__":
# --> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X13sZmlsZQ%3D%3D?line=170'>171</a>     main()
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 7 line 1
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X13sZmlsZQ%3D%3D?line=163'>164</a>     pantalla_juego()
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X13sZmlsZQ%3D%3D?line=165'>166</a> pygame.display.flip()
# ...

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 900, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 24)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultado de la partida
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

# Puntaje del jugador
puntaje = 0

# Variable para controlar la pantalla actual
pantalla_actual = 1

# Variables para almacenar las elecciones del jugador y la computadora
resultado_jugador = ""
resultado_computadora = ""

def cargar_imagen(nombre_archivo):
    return pygame.image.load(nombre_archivo).convert_alpha()


# Cargar imágenes de las elecciones (piedra, papel y tijera)
img_piedra = cargar_imagen("./images/piedra.png")
img_papel = cargar_imagen("./images/papel.png")
img_tijera = cargar_imagen("./images/tijera.png")

# Posiciones de las imágenes de elecciones
pos_piedra = (155, 438)
pos_papel = (376, 405)
pos_tijera = (585, 402)

#images
background = pygame.image.load("./images/Frame_8.jpg").convert()
background2 = pygame.image.load("./images/background2.jpg").convert()



font = pygame.font.Font("./images/Mantana-Regular.otf", 18)

def pantalla_1():
    global nickname, pantalla_actual
    screen.blit(background, (0, 0))
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    

    screen.blit(texto_ingrese_nickname, (200, 282))
    
    pygame.draw.rect(screen, WHITE, (200, 282, 600, 50))  # Cuadro de entrada
    
    # Obtener el texto ingresado en el campo de entrada
    input_text = font.render(nickname, True, (0, 0, 0))
    screen.blit(input_text, (300, 282))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    if pantalla_actual == 1:
        # Botón para iniciar el juego
        pygame.draw.rect(screen, RED, (350, 400, 200, 50))
        texto_iniciar = font.render("Enter para empezar el juego", True, (0, 0, 0))
        screen.blit(texto_iniciar, (360, 0))

def pantalla_juego():
    global resultado, puntaje
    screen.blit(background2, (0, 0))
    
    # Mostrar nickname y puntaje
    texto_nickname = font.render(f"Nickname: {nickname}", True, (0, 0, 0))
    screen.blit(texto_nickname, (10, 10))
    
    texto_puntaje = font.render(f"Puntaje: {puntaje}", True, (0, 0, 0))
    screen.blit(texto_puntaje, (10, 50))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    # Botón para repetir partida
    pygame.draw.rect(screen, RED, (350, 500, 200, 50))
    texto_repetir = font.render("Presione R para repetir partida", True, (0, 0, 0))

    screen.blit(texto_repetir, (299, 559))
    screen.blit(img_piedra, pos_piedra)
    screen.blit(img_papel, pos_papel)
    screen.blit(img_tijera, pos_tijera)

    # Mostrar imágenes de las elecciones del jugador y la computadora
    if pantalla_actual == 2:
        if resultado:
            # Mostrar la elección del jugador
            if resultado_jugador == "Piedra":
                screen.blit(img_piedra, (250, 250))
            elif resultado_jugador == "Papel":
                screen.blit(img_papel, (250, 250))
            elif resultado_jugador == "Tijera":
                screen.blit(img_tijera, (250, 250))
            
            # Mostrar la elección de la computadora
            if resultado_computadora == "Piedra":
                screen.blit(img_piedra, (450, 250))
            elif resultado_computadora == "Papel":
                screen.blit(img_papel, (450, 250))
            elif resultado_computadora == "Tijera":
                screen.blit(img_tijera, (450, 250))
        else:
            # Mostrar las opciones para que el jugador elija
            screen.blit(img_piedra, pos_piedra)
            screen.blit(img_papel, pos_papel)
            screen.blit(img_tijera, pos_tijera)

def reiniciar_partida():
    global resultado, puntaje
    resultado = ""
    puntaje = 0

def jugar_eleccion(jugador):
    global resultado, puntaje, resultado_jugador, resultado_computadora
    computadora = random.choice(elecciones)
    
    resultado_jugador = jugador
    resultado_computadora = computadora
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
        puntaje += 1
    else:
        resultado = "¡Perdiste!"
        puntaje -= 1
    
    return computadora

def manejar_eventos():
    global nickname, pantalla_actual, running  # Agregamos "running" a las variables globales
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
       
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_s:
                # Presionar la tecla "S" para salir del juego
                pygame.quit()
                sys.exit()
                
            if pantalla_actual == 1:
                if event.key == pygame.K_BACKSPACE:
                    nickname = nickname[:-1]
                elif event.key == pygame.K_RETURN:
                    if nickname:
                        pantalla_actual = 2
                else:
                    nickname += event.unicode
            elif pantalla_actual == 2:
                if event.key == pygame.K_r:
                    # Reiniciar la partida
                    reiniciar_partida()
                elif event.key == pygame.K_p:
                    # El jugador seleccionó "Piedra"
                    jugar_eleccion("Piedra")
                elif event.key == pygame.K_a:
                    # El jugador seleccionó "Papel"
                    jugar_eleccion("Papel")
                elif event.key == pygame.K_t:
                    # El jugador seleccionó "Tijera"
                    jugar_eleccion("Tijera")

def main():
    global resultado, nickname, running
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_juego()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
import pygame
import sys
import random

pygame.init()

WIDTH, HEIGHT = 800, 600
screen = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Piedra, Papel o Tijera en Pygame")

# Colores
WHITE = (255, 255, 255)
RED = (255, 0, 0)

# Fuente
font = pygame.font.Font(None, 36)

# Elecciones del jugador y de la computadora
elecciones = ["Piedra", "Papel", "Tijera"]

# Resultado de la partida
resultado = ""

# Campo de entrada de texto para el apodo (nickname)
nickname = ""

# Puntaje del jugador
puntaje = 0

# Variable para controlar la pantalla actual
pantalla_actual = 1

def cargar_imagen(nombre_archivo):
    return pygame.image.load(nombre_archivo).convert_alpha()


# Cargar imágenes de las elecciones (piedra, papel y tijera)
img_piedra = cargar_imagen("./images/piedra.png")
img_papel = cargar_imagen("./images/piedra.png")
img_tijera = cargar_imagen("./images/piedra.png")

# Posiciones de las imágenes de elecciones
pos_piedra = (150, 350)
pos_papel = (350, 350)
pos_tijera = (550, 350)

def pantalla_1():
    global nickname, pantalla_actual
    screen.fill(WHITE)
    
    # Campo de entrada de texto
    texto_ingrese_nickname = font.render("Ingrese su nickname:", True, (0, 0, 0))
    screen.blit(texto_ingrese_nickname, (100, 200))
    
    pygame.draw.rect(screen, RED, (100, 250, 600, 50))  # Cuadro de entrada
    
    # Obtener el texto ingresado en el campo de entrada
    input_text = font.render(nickname, True, (0, 0, 0))
    screen.blit(input_text, (110, 260))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    if pantalla_actual == 1:
        # Botón para iniciar el juego
        pygame.draw.rect(screen, RED, (350, 400, 200, 50))
        texto_iniciar = font.render("Iniciar Juego", True, (0, 0, 0))
        screen.blit(texto_iniciar, (360, 410))

def pantalla_juego():
    global resultado, puntaje
    screen.fill(WHITE)
    
    # Mostrar nickname y puntaje
    texto_nickname = font.render(f"Nickname: {nickname}", True, (0, 0, 0))
    screen.blit(texto_nickname, (10, 10))
    
    texto_puntaje = font.render(f"Puntaje: {puntaje}", True, (0, 0, 0))
    screen.blit(texto_puntaje, (10, 50))
    
    if resultado:
        texto_resultado = font.render(f"Resultado: {resultado}", True, (0, 0, 0))
        screen.blit(texto_resultado, (300, 100))
    
    # Botón para repetir partida
    pygame.draw.rect(screen, RED, (350, 500, 200, 50))
    texto_repetir = font.render("Repetir Partida", True, (0, 0, 0))
    screen.blit(texto_repetir, (360, 510))

    # Mostrar imágenes de las elecciones solo en la segunda pantalla
    if pantalla_actual == 2:
        screen.blit(img_piedra, pos_piedra)
        screen.blit(img_papel, pos_papel)
        screen.blit(img_tijera, pos_tijera)

def reiniciar_partida():
    global resultado, puntaje
    resultado = ""
    puntaje = 0

def jugar_eleccion(jugador):
    global resultado, puntaje
    computadora = random.choice(elecciones)
    
    if jugador == computadora:
        resultado = "Empate"
    elif (jugador == "Piedra" and computadora == "Tijera") or \
         (jugador == "Papel" and computadora == "Piedra") or \
         (jugador == "Tijera" and computadora == "Papel"):
        resultado = "¡Ganaste!"
        puntaje += 1
    else:
        resultado = "¡Perdiste!"
        puntaje -= 1
    
    return computadora

def manejar_eventos():
    global nickname, pantalla_actual
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            sys.exit()
       
        elif event.type == pygame.KEYDOWN:
            if pantalla_actual == 1:
                if event.key == pygame.K_BACKSPACE:
                    nickname = nickname[:-1]
                elif event.key == pygame.K_RETURN:
                    if nickname:
                        pantalla_actual = 2
                else:
                    nickname += event.unicode
            elif pantalla_actual == 2:
                if event.key == pygame.K_r:
                    # Reiniciar la partida
                    reiniciar_partida()
                elif event.key == pygame.K_p:
                    # El jugador seleccionó "Piedra"
                    resultado_jugador = jugar_eleccion("Piedra")
                elif event.key == pygame.K_a:
                    # El jugador seleccionó "Papel"
                    resultado_jugador = jugar_eleccion("Papel")
                elif event.key == pygame.K_t:
                    # El jugador seleccionó "Tijera"
                    resultado_jugador = jugar_eleccion("Tijera")

def main():
    global resultado, nickname
    running = True
    clock = pygame.time.Clock()
    
    while running:
        manejar_eventos()
        if pantalla_actual == 1:
            pantalla_1()
        elif pantalla_actual == 2:
            pantalla_juego()
        
        pygame.display.flip()
        
        clock.tick(60)  # Límite de velocidad de cuadros

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 6 line 1
#
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=162'>163</a>         clock.tick(60)  # Límite de velocidad de cuadros
#
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=164'>165</a> if __name__ == "__main__":
#
# --> <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=165'>166</a>     main()
#
#
#
# /Users/Fernanda/Downloads/Tareas/game.ipynb Celda 6 line 1
#
#     <a href='vscode-notebook-cell:/Users/Fernanda/Downloads/Tareas/game.ipynb#X12sZmlsZQ%3D%3D?line=158'>159</a>     pantalla_juego()
#
# ...
